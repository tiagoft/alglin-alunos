90203911, -1.00251430, -1.22665066, 1.75633284,  0.43352242, -0.75477424], [-1.23012278, 0.67712930, 1.27639422, 0.61868472, 0.11894143,  -0.41549268, -0.81985991], [-0.37473648, 0.13318863, 1.33125325, 2.01333805, 0.75591191, 0.19919542,  1.43129280], [0.58670785, -0.12125439, -1.55803318, -0.59259582, -0.81063605,  -1.91465517, 0.23351972], [-1.20020752, 1.19959479, 0.43342273, -1.41856971, -1.00141958,  -0.32104025, -0.30523587], [0.92608433, -0.45058346, 1.29207707, 1.34142357, 1.38791146, 1.52349433,  -0.11733120], [0.87104366, 0.21972894, 0.04025358, -0.52904882, -0.52292093,  -0.70264635, 0.64481838]])
print(dados.shape)

# Esta questão esta errada de acordo com o professor.
# Out:
# (30, 7)

# %% [markdown]
# ### Questão 2

# %% [markdown]
# Os autovalores w e os autovetores v abaixo foram calculados sobre uma matriz de covariância de um conjunto de dados. Sendo que os valores na coluna v[:,i] são os autovetores correspondentes ao autovalor w[i], responda:

# %% [markdown]
# ```python
# import numpy as np
#
# v = np.array([[-0.74421937, -0.29243390, 0.18129478, -0.56696162, -0.07938097,  0.00230774], [-0.53896840, 0.24399594, -0.03656136, 0.50382462, 0.48381402,  0.40090779], [0.19837474, -0.52850656, 0.57837312, 0.21823586, -0.13521262,  0.53000327], [-0.22836585, -0.00918770, -0.44968877, 0.27076634, -0.77860426,  0.25691559], [-0.19438314, 0.43417221, 0.64048122, 0.28357277, -0.35126994,  -0.39961156], [0.16236465, 0.62212481, 0.13727277, -0.47261026, -0.10828220,  0.57677477]])
# w = np.array([1.99366318, 1.40229286, 0.87617268, 0.78149927, 0.50746899, 0.41832565])
#
# ```

# %%
import numpy as np

v = np.array([[-0.74421937, -0.29243390, 0.18129478, -0.56696162, -0.07938097,  0.00230774], [-0.53896840, 0.24399594, -0.03656136, 0.50382462, 0.48381402,  0.40090779], [0.19837474, -0.52850656, 0.57837312, 0.21823586, -0.13521262,  0.53000327], [-0.22836585, -0.00918770, -0.44968877, 0.27076634, -0.77860426,  0.25691559], [-0.19438314, 0.43417221, 0.64048122, 0.28357277, -0.35126994,  -0.39961156], [0.16236465, 0.62212481, 0.13727277, -0.47261026, -0.10828220,  0.57677477]])
w = np.array([1.99366318, 1.40229286, 0.87617268, 0.78149927, 0.50746899, 0.41832565])


# quantas features existem?
features = 0
for item in v:
    features += 1

print(features)

# O número de features do conjunto de dados pode ser obtido a partir do número de colunas da matriz de autovetores v. 
# Como cada coluna representa um vetor correspondente a uma feature, o número de features é igual ao número de colunas de v. 
# Portanto, o conjunto de dados possui 6 features, já que v tem 6 colunas.


proj_matrix = v[:, :2]
print(proj_matrix)
# Out:
# 6
# [[-0.74421937 -0.2924339 ]
#  [-0.5389684   0.24399594]
#  [ 0.19837474 -0.52850656]
#  [-0.22836585 -0.0091877 ]
#  [-0.19438314  0.43417221]
#  [ 0.16236465  0.62212481]]
