# %%
import numpy as np

A = np.array([[0.69, 0.15, 0.42, 0.78, 0.38], [0.98, 0.78, 0.13, 0.12, 0.10], [0.71, 0.58, 0.93, 0.06, 0.71], [0.98, 0.84, 0.40, 0.73, 0.92]])
B = np.array([[0.35, 0.36, 0.02, 0.47, 0.46], [0.27, 1.00, 0.95, 0.83, 0.92], [0.60, 0.08, 0.12, 0.76, 0.84], [0.69, 0.85, 0.72, 0.66, 0.92], [0.99, 0.74, 0.07, 0.81, 0.46]])
C = np.array([[0.18, 0.35, 0.21, 0.59, 0.02, 0.70], [0.84, 0.52, 1.00, 0.20, 0.66, 0.78], [0.74, 0.28, 0.23, 0.19, 0.40, 0.22], [0.12, 0.23, 0.92, 0.30, 0.46, 0.69], [0.21, 0.75, 0.75, 0.57, 0.47, 0.67]])

# %%
Y = np.dot(np.dot(A,B),C)
print(Y)

# Separar por vírgula
Y = np.array2string(Y, separator=',')
print(Y)
# Out:
# [[2.552944 3.086424 4.601993 2.727349 2.786178 4.49911 ]
#  [2.363224 2.604072 4.023162 2.13645  2.53758  3.693678]
#  [2.80675  3.594852 5.505057 3.245093 3.256792 5.353704]
#  [4.479522 5.108869 7.792487 4.413769 4.778368 7.48132 ]]
# [[2.552944,3.086424,4.601993,2.727349,2.786178,4.49911 ],
#  [2.363224,2.604072,4.023162,2.13645 ,2.53758 ,3.693678],
#  [2.80675 ,3.594852,5.505057,3.245093,3.256792,5.353704],
#  [4.479522,5.108869,7.792487,4.413769,4.778368,7.48132 ]]

# %%
A = np.array([[0.55, 0.78, 0.12, 0.05, 0.40, 0.03, 0.45, 0.30, 0.31, 0.07, 0.68, 0.79], [0.17, 0.60, 0.71, 0.83, 0.68, 0.82, 0.68, 0.66, 0.26, 0.03, 0.59, 0.89], [0.28, 0.87, 0.57, 0.86, 0.07, 0.88, 0.07, 0.46, 0.65, 0.62, 0.09, 0.78], [0.48, 0.15, 0.11, 0.22, 0.98, 0.68, 0.42, 0.64, 0.77, 0.97, 0.43, 0.40], [0.95, 0.61, 0.92, 0.13, 0.41, 0.52, 0.11, 0.63, 0.48, 0.49, 0.08, 0.83], [0.41, 0.96, 0.08, 0.64, 0.14, 0.73, 0.10, 0.99, 0.15, 0.44, 0.45, 0.81], [0.92, 0.30, 0.83, 0.59, 0.17, 0.87, 0.23, 0.93, 0.46, 0.45, 0.91, 0.09], [0.32, 0.39, 0.61, 0.90, 0.28, 0.98, 0.80, 0.09, 0.02, 0.96, 0.73, 0.63]])
B = np.array([[0.50, 0.83, 0.76, 0.93, 0.77, 0.34, 0.97, 0.45], [0.52, 0.05, 0.02, 0.51, 0.13, 0.91, 0.00, 0.19], [0.60, 0.86, 0.70, 0.60, 0.66, 0.83, 0.43, 0.11], [0.58, 0.60, 0.08, 0.89, 0.77, 0.62, 0.85, 0.64], [0.09, 0.32, 0.84, 0.24, 0.45, 0.76, 0.80, 0.65], [0.99, 0.18, 0.38, 0.06, 0.17, 0.90, 0.46, 0.00], [0.49, 0.58, 0.44, 0.36, 0.20, 0.47, 0.33, 0.56], [0.45, 0.44, 0.39, 0.72, 0.32, 0.49, 0.38, 0.13], [0.58, 0.68, 0.10, 0.18, 0.30, 0.40, 0.57, 0.92], [0.32, 0.82, 0.46, 0.61, 0.42, 0.49, 0.96, 0.92], [0.96, 0.31, 0.26, 0.90, 0.92, 0.87, 0.88, 0.82], [0.63, 0.64, 0.33, 0.35, 0.72, 0.08, 0.93, 0.77]])

Y = np.dot(A,B)
Y = np.array2string(Y, separator=',')
print(Y)
# Out:
# [[2.5555,2.1397,1.6847,2.4886,2.3305,2.53  ,2.8009,2.5074],
#  [4.0951,3.2836,2.6309,3.4688,3.3834,4.3087,4.096 ,3.1443],
#  [3.7052,3.1834,1.9324,3.0867,2.8092,3.7012,3.6767,2.8917],
#  [3.1886,3.302 ,2.7454,2.93  ,2.7985,3.5846,4.299 ,3.6142],
#  [3.3436,3.5382,2.7928,3.2329,3.0356,3.4304,3.8568,2.7349],
#  [3.5233,2.6316,1.8648,3.2986,2.737 ,3.5036,3.4903,2.5965],
#  [4.2051,3.6215,2.79  ,4.0849,3.5465,4.3199,4.295 ,2.9528],
#  [4.0952,3.5496,2.586 ,3.609 ,3.4085,4.2068,4.472 ,3.4882]]

# %%
#Sistemas Lineares 3

import numpy as np

A = np.array([[1.50, 1.10], [0.50, 1.40]])
B = np.array([[0.20, 1.80], [0.20, 0.60]])
C = np.array([[0.40, 0.40], [0.80, 1.70]])

A_1 = np.linalg.inv(A)
B_1 = np.linalg.inv(B)
X = np.dot(A_1,np.dot(C,B_1))
X = np.array2string(X, separator=',')
print(X)
# Out:
# [[-0.18817204,-0.84408602],
#  [-0.34946237, 3.57526882]]

# %%
import numpy as np

A = np.array([[0.90, 1.80], [0.40, 1.40]])
B = np.array([[0.50, 0.80], [0.80, 1.30]])
C = np.array([[0.80, 1.70], [1.60, 0.20]])

#[[-2.74060273e+11,  2.60176829e+11],  [ 1.04286670e+11, -9.90036785e+10]]

#ABABBABAX= C
# Calcule X
# Isolar X

X = np.dot(np.linalg.inv(np.dot(A,B)),np.dot(B,A))
X = np.array2string(X, separator=',')
print(X)
# Out:
# [[ -397.51851852,-1046.81481481],
#  [  245.77777778,  647.22222222]]

# %%
# Dado o sistema linear abaixo, calcule o valor das incógnitas em ordem:

  
# +9.9a +5.3b +6.0c +3.2d +5.9e +4.8f +0.8g  = 6.3 
# +7.4a +9.9b +1.5c +3.2d +6.0e +1.3f +8.1g  = 3.3 
# +0.4a +6.8b +3.1c +2.6d +5.4e +4.0f +6.7g  = 0.6 
# +8.8a +2.4b +0.1c +8.4d +9.9e +0.6f +0.3g  = 6.1 
# +7.5a +10.0b +9.2c +2.3d +9.9e +7.2f +6.3g  = 6.4 
# +9.1a +0.0b +3.0c +8.9d +1.7e +8.7f +9.0g  = 8.3 
# +4.4a +3.7b +2.7c +2.4d +4.4e +7.4f +5.1g  = 9.2 

# A = np.array([[9.9, 5.3, 6.0, 3.2, 5.9, 4.8, 0.8], [7.4, 9.9, 1.5, 3.2, 6.0, 1.3, 8.1], [0.4, 6.8, 3.1, 2.6, 5.4, 4.0, 6.7], [8.8, 2.4, 0.1, 8.4, 9.9, 0.6, 0.3], [7.5, 10.0, 9.2, 2.3, 9.9, 7.2, 6.3], [9.1, 0.0, 3.0, 8.9, 1.7, 8.7, 9.0], [4.4, 3.7, 2.7, 2.4, 4.4, 7.4, 5.1]])
# B = np.array([6.3, 3.3, 0.6, 6.1, 6.4, 8.3, 9.2])

import numpy as np

A_1 = np.linalg.inv(A)
X = np.dot(A_1,B)
X = np.array2string(X, separator=',')
print(X)
# Out:
# [ 0.86052871,-0.68062309,-0.95489623,-1.09588022, 0.88260213, 1.08948003,
#   0.23425683]

# %%
# Dado o sistema linear abaixo, calcule o valor das incógnitas em ordem:

# +2.1a +4.8b +3.4c +9.7d +2.7e +1.7f +4.6g  = 6.5 
# +9.5a +0.6b +4.5c +6.9d +0.9e +1.8f +3.9g  = 2.2 
# +5.2a +0.4b +3.4c +1.4d +6.2e +8.8f +7.2g  = 8.5 
# +1.3a +2.8b +6.8c +9.2d +8.0e +9.3f +7.0g  = 2.5 
# +9.5a +5.6b +2.2c +2.2d +6.6e +3.8f +5.2g  = 4.4 
# +1.7a +8.6b +2.7c +6.0d +2.0e +9.6f +1.9g  = 7.5 
# +3.4a +9.2b +3.8c +9.8d +1.7e +9.7f +2.0g  = 0.7

import numpy as np

A = np.array([[2.1, 4.8, 3.4, 9.7, 2.7, 1.7, 4.6], [9.5, 0.6, 4.5, 6.9, 0.9, 1.8, 3.9], [5.2, 0.4, 3.4, 1.4, 6.2, 8.8, 7.2], [1.3, 2.8, 6.8, 9.2, 8.0, 9.3, 7.0], [9.5, 5.6, 2.2, 2.2, 6.6, 3.8, 5.2], [1.7, 8.6, 2.7, 6.0, 2.0, 9.6, 1.9], [3.4, 9.2, 3.8, 9.8, 1.7, 9.7, 2.0]])
B = np.array([6.5, 2.2, 8.5, 2.5, 4.4, 7.5, 0.7])

A_1 = np.linalg.inv(A)
X = np.dot(A_1,B)
X = np.array2string(X, separator=',')
print(X)
# Out:
# [-1.39440156, 3.24992635, 5.39208107,-3.66344393,-4.05055938,-1.306974  ,
#   5.25854205]
